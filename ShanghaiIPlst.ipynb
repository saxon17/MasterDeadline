# %%
import pickle
import pprint 
import pandas as pd

DASH = open('F:\youtube_proj\yip\DASH.yip', 'rb')
iphone4g = open('F:\youtube_proj\yip\iphone4g.yip', 'rb')
iphoneweb =  open('F:\youtube_proj\yip\iphoneweb-safari.yip', 'rb')
sanchr = open('F:\youtube_proj\yip\sanchr.yip', 'rb')
sanzidai = open('F:\youtube_proj\yip\sanzidai.yip', 'rb')

das = pickle.load(DASH)
i4g = pickle.load(iphone4g)
iweb = pickle.load(iphoneweb)
sanchr = pickle.load(sanchr)
sanzidai = pickle.load(sanzidai)

pklst = [das,i4g,iweb,sanchr,sanzidai]
FinalIPSET  = {}
for ipdict in pklst:
      FinalIPSET.update(ipdict)

# pprint.pprint(FinalIPSET)

s = pd.Series(FinalIPSET, name = 'Youtube Server Name')
s.index.name = 'YoutubeIP'
s.reset_index()
# Out:
#           YoutubeIP               Youtube Server Name
# 0    173.194.152.44    r6.sn-nx5e6n76.googlevideo.com
# 1     173.194.152.7    r1.sn-nx5e6n7s.googlevideo.com
# 2    173.194.22.135  r1---sn-i3b7rn7k.googlevideo.com
# 3    173.194.22.136  r2---sn-i3b7rn7k.googlevideo.com
# 4    173.194.22.137    r3.sn-i3b7rn7k.googlevideo.com
# 5    173.194.22.138    r4.sn-i3b7rn7k.googlevideo.com
# 6    173.194.22.139  r5---sn-i3b7rn7k.googlevideo.com
# 7    173.194.22.140    r6.sn-i3b7rn7k.googlevideo.com
# 8    173.194.22.151  r1---sn-i3b7rn7r.googlevideo.com
# 9    173.194.22.152    r2.sn-i3b7rn7r.googlevideo.com
# 10   173.194.22.153  r3---sn-i3b7rn7r.googlevideo.com
# 11   173.194.22.156    r6.sn-i3b7rn7r.googlevideo.com
# 12   173.194.22.167    r1.sn-i3b7rn7y.googlevideo.com
# 13   173.194.22.168    r2.sn-i3b7rn7y.googlevideo.com
# 14   173.194.22.169  r3---sn-i3b7rn7y.googlevideo.com
# 15   173.194.22.170  r4---sn-i3b7rn7y.googlevideo.com
# 16   173.194.22.171  r5---sn-i3b7rn7y.googlevideo.com
# 17   173.194.22.172    r6.sn-i3b7rn7y.googlevideo.com
# 18   173.194.22.183    r1.sn-i3b7rne7.googlevideo.com
# 19   173.194.22.184    r2.sn-i3b7rne7.googlevideo.com
# 20   173.194.22.185    r3.sn-i3b7rne7.googlevideo.com
# 21   173.194.22.186  r4---sn-i3b7rne7.googlevideo.com
# 22   173.194.22.187  r5---sn-i3b7rne7.googlevideo.com
# 23   173.194.22.188    r6.sn-i3b7rne7.googlevideo.com
# 24   173.194.22.199    r1.sn-i3b7rnee.googlevideo.com
# 25   173.194.22.200    r2.sn-i3b7rnee.googlevideo.com
# 26   173.194.22.201  r3---sn-i3b7rnee.googlevideo.com
# 27   173.194.22.202    r4.sn-i3b7rnee.googlevideo.com
# 28   173.194.22.203  r5---sn-i3b7rnee.googlevideo.com
# 29   173.194.22.215  r1---sn-i3b7rnel.googlevideo.com
# 30   173.194.22.216    r2.sn-i3b7rnel.googlevideo.com
# 31   173.194.22.217  r3---sn-i3b7rnel.googlevideo.com
# 32   173.194.22.218  r4---sn-i3b7rnel.googlevideo.com
# 33   173.194.22.219    r5.sn-i3b7rnel.googlevideo.com
# 34   173.194.22.220    r6.sn-i3b7rnel.googlevideo.com
# 35   173.194.54.135    r2.sn-vgqs7nek.googlevideo.com
# 36    173.194.54.75    r6.sn-vgqs7ne6.googlevideo.com
# 37    173.194.55.56    r2.sn-vgqsenl7.googlevideo.com
# 38    173.194.55.92    r6.sn-vgqsenlz.googlevideo.com
# 39  208.117.238.169    r4.sn-aigllm7d.googlevideo.com
# 40     74.125.164.9  r4---sn-i3b7kne7.googlevideo.com
# 41   74.125.215.115    r4.sn-a5m7zu7z.googlevideo.com
# 42    74.125.215.16    r1.sn-a5m7zu7e.googlevideo.com
# 43   74.125.215.209    r2.sn-a5m7zu7k.googlevideo.com
# 44   74.125.215.241    r2.sn-a5m7zu7r.googlevideo.com
# 45    74.125.215.55  r8---sn-a5m7zu7l.googlevideo.com
# 46    74.125.215.83  r4---sn-a5m7zu7s.googlevideo.com
